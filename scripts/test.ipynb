# %%
import gymnasium as gym
import numpy as np
import torch
import open3d as o3d
from gymnasium import spaces
import copy
from stable_baselines3 import PPO
import matplotlib.pyplot as plt
import copy
import os
import sys
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# 2024-10-14 18:49:27.340629: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-14 18:49:27.342037: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-14 18:49:27.369560: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
sys.path.append("/home/dir/RL_CoveragePlanning/viewpointPlaygroundEnv/viewpoint_env")

# %%
from viewpointWorld import CoverageEnv

# %%
def test_agent(env_name, model_path, num_episodes=10, render=True):
    # Create the environment
    env = env_name

    # Load the trained model
    model = PPO.load(model_path)

    for episode in range(num_episodes):
        obs, _ = env.reset()
        done = False
        total_reward = 0
        step = 0

        while not done:
            # Get the model's action
            action, _ = model.predict(obs, deterministic=True)

            # Take the action in the environment
            obs, reward, done, info, _ = env.step(action)

            total_reward += reward
            step += 1

            if render:
                env.render()

        print(f"Episode {episode + 1}: Total Reward: {total_reward}, Steps: {step}")

    env.close()

# %%
env_name = CoverageEnv() # Replace with your actual environment name
model_path = "/home/dir/RL_CoveragePlanning/rl-baselines3-zoo/logs/ppo/CoverageEnv-v0_9/rl_model_9996800_steps.zip"  # Replace with the path to your trained model
num_episodes = 5  # Number of episodes to run

test_agent(env_name, model_path, num_episodes, render=False)
# Out:
# Using test_7.obj
# /home/dir/RL_CoveragePlanning/viewpointPlaygroundEnv/viewpoint_env/viewpointWorld.py:71: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at ../aten/src/ATen/native/Cross.cpp:62.)
#   face_normals = torch.cross(self.vertices[self.faces[:, 1]] - self.vertices[self.faces[:, 0]],
# Reward: 4480.0 | Action: tensor([-0.0028,  0.0016], device='cuda:0') | Coverage: 44.81%
# Reward: 124.0 | Action: tensor([-0.0631,  0.0183], device='cuda:0') | Coverage: 46.07%
# Reward: -3.0 | Action: tensor([-0.0601,  0.0202], device='cuda:0') | Coverage: 46.07%
# Reward: -4.0 | Action: tensor([-0.0601,  0.0202], device='cuda:0') | Coverage: 46.07%
# Reward: -5.0 | Action: tensor([-0.0601,  0.0202], device='cuda:0') | Coverage: 46.07%
# ...
